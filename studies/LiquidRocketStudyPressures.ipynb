# %%
import os
import numpy as np
from hytempo.core import rocketfactory,trajectory_estimator,components,rocket,plotting,data_handling
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# Setup Parameters

# %%
"create components"
#create structures
nosecone = components.Component(mass=1,name="structures",length=0.53,hulltube=False)
radaxe = components.Component(mass=2.0,name="radaxe",length=0.05,hulltube=False)
finnen = components.Component(mass=2.0,name="fins",length=0.0,hulltube=False)
boattail = components.Component(mass=0.200,name="boattail",length=0.0,hulltube=False)

# subsystems
avionic = components.Component(mass=1.8,name="avionic",length=0.25,hulltube=True)
recovery = components.Component(mass=4.020,name="recovery",length=0.25,hulltube=True)
fluid_system = components.Component(mass=7.0,name="fluid_system",length=0.98,hulltube=True)
parts = []

parts.append(nosecone)
parts.append(radaxe)
parts.append(finnen)
parts.append(boattail)
parts.append(avionic)
parts.append(recovery)
parts.append(fluid_system)


"Import CD LUT"
absolute_path = os.path.dirname(os.path.abspath("__file__"))
relative_path = "hytempo\LUTs\CD_Map.csv"
absolute_path = absolute_path[:absolute_path.rfind("\\") ]                 
path = os.path.join(absolute_path, relative_path)
CD_tab = np.genfromtxt(path, delimiter=";")

"Setup variables"
#diameters = [0.1,0.2]
#burn_times = [10,15]
#thrust = [1000,2000]
#of = [4.5,6]
chamberPressure = [5e6,8e6]
#expansionRatio = [10,20]
pressurantPressureFactor = [2,6]
#launch_angle = [80,85]

diameters = 0.25
burn_times = 20
thrust = 8000
of = 4.8
#chamberPressure = 6e6
expansionRatio = 10
#pressurantPressureFactor = 5
launch_angle = 88

# %% [markdown]
# Build and simulate the rockets

# %%
#create the hdf5 file
name = "LiquidSim"
hdf_file = data_handling.create_hdf5_file(name, overwrite=False)

#create rockets
factory = rocketfactory.Liquid_CEA_TypeVTank_RegNitrous()
rockets = factory.build_swarm(
    hdf_file=hdf_file,
    diameters = diameters,
    burnTimes = burn_times,
    thrusts = thrust,
    ofs = of,
    chamberPressures = chamberPressure,
    expansionRatios = expansionRatio,
    pressurantPressureFactors = pressurantPressureFactor,
    launchAngles=launch_angle,
    componentList=parts,
    fuel="ETHANOL",
    fuelTemp=300,
    ox="N2O",
    oxTemp=300,
    pressurant="HELIUM",
    pressurantTemp=300,
    dragCoefficient=CD_tab,
    engineMass=4,
    engineLength=0.3,
    fuelTankSafetyFactor=1.5,
    oxTankSafetyFactor=1.5,
    pressurantTankSafetyFactor=1.5,
    thicknessEndCap=0.0015,
    cfrpTensileStrength=600e6,
    nRockets=1000)

#loop over rockets and simulate trajectories
print(f"Start simulating {len(rockets)} rockets...")
for i,indRocket in enumerate(rockets):
    #create estimator and simulate trajectory
    print(f"Simulating rocket {i+1} of {len(rockets)}: {indRocket.name}")
    sim = trajectory_estimator.TrajectoryEstimator(indRocket,hdf_file)
    try:
        trajectory = sim.integrate_trajectory()
    except Exception as e:
        print("ERROR:")
        print(e)
        print(f"Simulation failed for rocket {indRocket.name} . Skipping...")
print("All rockets simulated. Closing hdf5 file...")    
#close the hdf5 file
file_path = data_handling.close_hdf5_file(hdf_file)
# Out:
# Setting up factory for rockets with:
#  - Single liquid engine with CEA isp model
#  - Type V CFK tanks for fuel, oxidizer and pressurant
#  - Regenerative cooling with Nitrous oxide
# Start building rockets!
# Buildung rocket:  1  of  1000
# Buildung rocket:  2  of  1000
# Buildung rocket:  3  of  1000
# Buildung rocket:  4  of  1000
# Buildung rocket:  5  of  1000
# Buildung rocket:  6  of  1000
# Buildung rocket:  7  of  1000
# Buildung rocket:  8  of  1000
# Buildung rocket:  9  of  1000
# Buildung rocket:  10  of  1000
# Buildung rocket:  11  of  1000
# Buildung rocket:  12  of  1000
# Buildung rocket:  13  of  1000
# Buildung rocket:  14  of  1000
# Buildung rocket:  15  of  1000
# Buildung rocket:  16  of  1000
# Buildung rocket:  17  of  1000
# Buildung rocket:  18  of  1000
# Buildung rocket:  19  of  1000
# Buildung rocket:  20  of  1000
# Buildung rocket:  21  of  1000
# Buildung rocket:  22  of  1000
# Buildung rocket:  23  of  1000
# Buildung rocket:  24  of  1000
# Buildung rocket:  25  of  1000
# Buildung rocket:  26  of  1000
# Buildung rocket:  27  of  1000
# Buildung rocket:  28  of  1000
# Buildung rocket:  29  of  1000
# Buildung rocket:  30  of  1000
# Buildung rocket:  31  of  1000
# Buildung rocket:  32  of  1000
# Buildung rocket:  33  of  1000
# Buildung rocket:  34  of  1000
# Buildung rocket:  35  of  1000
# Buildung rocket:  36  of  1000
# Buildung rocket:  37  of  1000
# Buildung rocket:  38  of  1000
# Buildung rocket:  39  of  1000
# Buildung rocket:  40  of  1000
# Buildung rocket:  41  of  1000
# Buildung rocket:  42  of  1000
# Buildung rocket:  43  of  1000
# Buildung rocket:  44  of  1000
# Buildung rocket:  45  of  1000
# Buildung rocket:  46  of  1000
# Buildung rocket:  47  of  1000
# Buildung rocket:  48  of  1000
# Buildung rocket:  49  of  1000
# Buildung rocket:  50  of  1000
# Buildung rocket:  51  of  1000
# Buildung rocket:  52  of  1000
# Buildung rocket:  53  of  1000
# Buildung rocket:  54  of  1000
# Buildung rocket:  55  of  1000
# Buildung rocket:  56  of  1000
# Buildung rocket:  57  of  1000
# Buildung rocket:  58  of  1000
# Buildung rocket:  59  of  1000
# Buildung rocket:  60  of  1000
# Buildung rocket:  61  of  1000
# Buildung rocket:  62  of  1000
# Buildung rocket:  63  of  1000
# Buildung rocket:  64  of  1000
# Buildung rocket:  65  of  1000
# Buildung rocket:  66  of  1000
# Buildung rocket:  67  of  1000
# Buildung rocket:  68  of  1000
# Buildung rocket:  69  of  1000
# Buildung rocket:  70  of  1000
# Buildung rocket:  71  of  1000
# Buildung rocket:  72  of  1000
# Buildung rocket:  73  of  1000
# Buildung rocket:  74  of  1000
# Buildung rocket:  75  of  1000
# Buildung rocket:  76  of  1000
# Buildung rocket:  77  of  1000
# Buildung rocket:  78  of  1000
# Buildung rocket:  79  of  1000
# Buildung rocket:  80  of  1000
# Buildung rocket:  81  of  1000
# Buildung rocket:  82  of  1000
# Buildung rocket:  83  of  1000
# Buildung rocket:  84  of  1000
# Buildung rocket:  85  of  1000
# Buildung rocket:  86  of  1000
# Buildung rocket:  87  of  1000
# Buildung rocket:  88  of  1000
# Buildung rocket:  89  of  1000
# Buildung rocket:  90  of  1000
# Buildung rocket:  91  of  1000
# Buildung rocket:  92  of  1000
# Buildung rocket:  93  of  1000
# Buildung rocket:  94  of  1000
# Buildung rocket:  95  of  1000
# Buildung rocket:  96  of  1000
# Buildung rocket:  97  of  1000
# Buildung rocket:  98  of  1000
# Buildung rocket:  99  of  1000
# Buildung rocket:  100  of  1000
# Buildung rocket:  101  of  1000
# Buildung rocket:  102  of  1000
# Buildung rocket:  103  of  1000
# Buildung rocket:  104  of  1000
# Buildung rocket:  105  of  1000
# Buildung rocket:  106  of  1000
# Buildung rocket:  107  of  1000
# Buildung rocket:  108  of  1000
# Buildung rocket:  109  of  1000
# Buildung rocket:  110  of  1000
# Buildung rocket:  111  of  1000
# Buildung rocket:  112  of  1000
# Buildung rocket:  113  of  1000
# Buildung rocket:  114  of  1000
# Buildung rocket:  115  of  1000
# Buildung rocket:  116  of  1000
# Buildung rocket:  117  of  1000
# Buildung rocket:  118  of  1000
# Buildung rocket:  119  of  1000
# Buildung rocket:  120  of  1000
# Buildung rocket:  121  of  1000
# Buildung rocket:  122  of  1000
# Buildung rocket:  123  of  1000
# Buildung rocket:  124  of  1000
# Buildung rocket:  125  of  1000
# Buildung rocket:  126  of  1000
# Buildung rocket:  127  of  1000
# Buildung rocket:  128  of  1000
# Buildung rocket:  129  of  1000
# Buildung rocket:  130  of  1000
# Buildung rocket:  131  of  1000
# Buildung rocket:  132  of  1000
# Buildung rocket:  133  of  1000
# Buildung rocket:  134  of  1000
# Buildung rocket:  135  of  1000
# Buildung rocket:  136  of  1000
# Buildung rocket:  137  of  1000
# Buildung rocket:  138  of  1000
# Buildung rocket:  139  of  1000
# Buildung rocket:  140  of  1000
# Buildung rocket:  141  of  1000
# Buildung rocket:  142  of  1000
# Buildung rocket:  143  of  1000
# Buildung rocket:  144  of  1000
# Buildung rocket:  145  of  1000
# Buildung rocket:  146  of  1000
# Buildung rocket:  147  of  1000
# Buildung rocket:  148  of  1000
# Buildung rocket:  149  of  1000
# Buildung rocket:  150  of  1000
# Buildung rocket:  151  of  1000
# Buildung rocket:  152  of  1000
# Buildung rocket:  153  of  1000
# Buildung rocket:  154  of  1000
# Buildung rocket:  155  of  1000
# Buildung rocket:  156  of  1000
# Buildung rocket:  157  of  1000
# Buildung rocket:  158  of  1000
# Buildung rocket:  159  of  1000
# Buildung rocket:  160  of  1000
# Buildung rocket:  161  of  1000
# Buildung rocket:  162  of  1000
# Buildung rocket:  163  of  1000
# Buildung rocket:  164  of  1000
# Buildung rocket:  165  of  1000
# Buildung rocket:  166  of  1000
# Buildung rocket:  167  of  1000
# Buildung rocket:  168  of  1000
# Buildung rocket:  169  of  1000
# Buildung rocket:  170  of  1000
# Buildung rocket:  171  of  1000
# Buildung rocket:  172  of  1000
# Buildung rocket:  173  of  1000
# Buildung rocket:  174  of  1000
# Buildung rocket:  175  of  1000
# Buildung rocket:  176  of  1000
# Buildung rocket:  177  of  1000
# Buildung rocket:  178  of  1000
# Buildung rocket:  179  of  1000
# Buildung rocket:  180  of  1000
# Buildung rocket:  181  of  1000
# Buildung rocket:  182  of  1000
# Buildung rocket:  183  of  1000
# Buildung rocket:  184  of  1000
# Buildung rocket:  185  of  1000
# Buildung rocket:  186  of  1000
# Buildung rocket:  187  of  1000
# Buildung rocket:  188  of  1000
# Buildung rocket:  189  of  1000
# Buildung rocket:  190  of  1000
# Buildung rocket:  191  of  1000
# Buildung rocket:  192  of  1000
# Buildung rocket:  193  of  1000
# Buildung rocket:  194  of  1000
# Buildung rocket:  195  of  1000
# Buildung rocket:  196  of  1000
# Buildung rocket:  197  of  1000
# Buildung rocket:  198  of  1000
# Buildung rocket:  199  of  1000
# Buildung rocket:  200  of  1000
# Buildung rocket:  201  of  1000
# Buildung rocket:  202  of  1000
# Buildung rocket:  203  of  1000
# Buildung rocket:  204  of  1000
# Buildung rocket:  205  of  1000
# Buildung rocket:  206  of  1000
# Buildung rocket:  207  of  1000
# Buildung rocket:  208  of  1000
# Buildung rocket:  209  of  1000
# Buildung rocket:  210  of  1000
# Buildung rocket:  211  of  1000
# Buildung rocket:  212  of  1000
# Buildung rocket:  213  of  1000
# Buildung rocket:  214  of  1000
# Buildung rocket:  215  of  1000
# Buildung rocket:  216  of  1000
# Buildung rocket:  217  of  1000
# Buildung rocket:  218  of  1000
# Buildung rocket:  219  of  1000
# Buildung rocket:  220  of  1000
# Buildung rocket:  221  of  1000
# Buildung rocket:  222  of  1000
# Buildung rocket:  223  of  1000
# Buildung rocket:  224  of  1000
# Buildung rocket:  225  of  1000
# Buildung rocket:  226  of  1000
# Buildung rocket:  227  of  1000
# Buildung rocket:  228  of  1000
# Buildung rocket:  229  of  1000
# Buildung rocket:  230  of  1000
# Buildung rocket:  231  of  1000
# Buildung rocket:  232  of  1000
# Buildung rocket:  233  of  1000
# Buildung rocket:  234  of  1000
# Buildung rocket:  235  of  1000
# Buildung rocket:  236  of  1000
# Buildung rocket:  237  of  1000
# Buildung rocket:  238  of  1000
# Buildung rocket:  239  of  1000
# Buildung rocket:  240  of  1000
# Buildung rocket:  241  of  1000
# Buildung rocket:  242  of  1000
# Buildung rocket:  243  of  1000
# Buildung rocket:  244  of  1000
# Buildung rocket:  245  of  1000
# Buildung rocket:  246  of  1000
# Buildung rocket:  247  of  1000
# Buildung rocket:  248  of  1000
# Buildung rocket:  249  of  1000
# Buildung rocket:  250  of  1000
# Buildung rocket:  251  of  1000
# Buildung rocket:  252  of  1000
# Buildung rocket:  253  of  1000
# Buildung rocket:  254  of  1000
# Buildung rocket:  255  of  1000
# Buildung rocket:  256  of  1000
# Buildung rocket:  257  of  1000
# Buildung rocket:  258  of  1000
# Buildung rocket:  259  of  1000
# Buildung rocket:  260  of  1000
# Buildung rocket:  261  of  1000
# Buildung rocket:  262  of  1000
# Buildung rocket:  263  of  1000
# Buildung rocket:  264  of  1000
# Buildung rocket:  265  of  1000
# Buildung rocket:  266  of  1000
# Buildung rocket:  267  of  1000
# Buildung rocket:  268  of  1000
# Buildung rocket:  269  of  1000
# Buildung rocket:  270  of  1000
# Buildung rocket:  271  of  1000
# Buildung rocket:  272  of  1000
# Buildung rocket:  273  of  1000
# Buildung rocket:  274  of  1000
# Buildung rocket:  275  of  1000
# Buildung rocket:  276  of  1000
# Buildung rocket:  277  of  1000
# Buildung rocket:  278  of  1000
# Buildung rocket:  279  of  1000
# Buildung rocket:  280  of  1000
# Buildung rocket:  281  of  1000
# Buildung rocket:  282  of  1000
# Buildung rocket:  283  of  1000
# Buildung rocket:  284  of  1000
# Buildung rocket:  285  of  1000
# Buildung rocket:  286  of  1000
# Buildung rocket:  287  of  1000
# Buildung rocket:  288  of  1000
# Buildung rocket:  289  of  1000
# Buildung rocket:  290  of  1000
# Buildung rocket:  291  of  1000
# Buildung rocket:  292  of  1000
# Buildung rocket:  293  of  1000
# Buildung rocket:  294  of  1000
# Buildung rocket:  295  of  1000
# Buildung rocket:  296  of  1000
# Buildung rocket:  297  of  1000
# Buildung rocket:  298  of  1000
# Buildung rocket:  299  of  1000
# Buildung rocket:  300  of  1000
# Buildung rocket:  301  of  1000
# Buildung rocket:  302  of  1000
# Buildung rocket:  303  of  1000
# Buildung rocket:  304  of  1000
# Buildung rocket:  305  of  1000
# Buildung rocket:  306  of  1000
# Buildung rocket:  307  of  1000
# Buildung rocket:  308  of  1000
# Buildung rocket:  309  of  1000
# Buildung rocket:  310  of  1000
# Buildung rocket:  311  of  1000
# Buildung rocket:  312  of  1000
# Buildung rocket:  313  of  1000
# Buildung rocket:  314  of  1000
# Buildung rocket:  315  of  1000
# Buildung rocket:  316  of  1000
# Buildung rocket:  317  of  1000
# Buildung rocket:  318  of  1000
# Buildung rocket:  319  of  1000
# Buildung rocket:  320  of  1000
# Buildung rocket:  321  of  1000
# Buildung rocket:  322  of  1000
# Buildung rocket:  323  of  1000
# Buildung rocket:  324  of  1000
# Buildung rocket:  325  of  1000
# Buildung rocket:  326  of  1000
# Buildung rocket:  327  of  1000
# Buildung rocket:  328  of  1000
# Buildung rocket:  329  of  1000
# Buildung rocket:  330  of  1000
# Buildung rocket:  331  of  1000
# Buildung rocket:  332  of  1000
# Buildung rocket:  333  of  1000
# Buildung rocket:  334  of  1000
# Buildung rocket:  335  of  1000
# Buildung rocket:  336  of  1000
# Buildung rocket:  337  of  1000
# Buildung rocket:  338  of  1000
# Buildung rocket:  339  of  1000
# Buildung rocket:  340  of  1000
# Buildung rocket:  341  of  1000
# Buildung rocket:  342  of  1000
# Buildung rocket:  343  of  1000
# Buildung rocket:  344  of  1000
# Buildung rocket:  345  of  1000
# Buildung rocket:  346  of  1000
# Buildung rocket:  347  of  1000
# Buildung rocket:  348  of  1000
# Buildung rocket:  349  of  1000
# Buildung rocket:  350  of  1000
# Buildung rocket:  351  of  1000
# Buildung rocket:  352  of  1000
# Buildung rocket:  353  of  1000
# Buildung rocket:  354  of  1000
# Buildung rocket:  355  of  1000
# Buildung rocket:  356  of  1000
# Buildung rocket:  357  of  1000
# Buildung rocket:  358  of  1000
# Buildung rocket:  359  of  1000
# Buildung rocket:  360  of  1000
# Buildung rocket:  361  of  1000
# Buildung rocket:  362  of  1000
# Buildung rocket:  363  of  1000
# Buildung rocket:  364  of  1000
# Buildung rocket:  365  of  1000
# Buildung rocket:  366  of  1000
# Buildung rocket:  367  of  1000
# Buildung rocket:  368  of  1000
# Buildung rocket:  369  of  1000
# Buildung rocket:  370  of  1000
# Buildung rocket:  371  of  1000
# Buildung rocket:  372  of  1000
# Buildung rocket:  373  of  1000
# Buildung rocket:  374  of  1000
# Buildung rocket:  375  of  1000
# Buildung rocket:  376  of  1000
# Buildung rocket:  377  of  1000
# Buildung rocket:  378  of  1000
# Buildung rocket:  379  of  1000
# Buildung rocket:  380  of  1000
# Buildung rocket:  381  of  1000
# Buildung rocket:  382  of  1000
# Buildung rocket:  383  of  1000
# Buildung rocket:  384  of  1000
# Buildung rocket:  385  of  1000
# Buildung rocket:  386  of  1000
# Buildung rocket:  387  of  1000
# Buildung rocket:  388  of  1000
# Buildung rocket:  389  of  1000
# Buildung rocket:  390  of  1000
# Buildung rocket:  391  of  1000
# Buildung rocket:  392  of  1000
# Buildung rocket:  393  of  1000
# Buildung rocket:  394  of  1000
# Buildung rocket:  395  of  1000
# Buildung rocket:  396  of  1000
# Buildung rocket:  397  of  1000
# Buildung rocket:  398  of  1000
# Buildung rocket:  399  of  1000
# Buildung rocket:  400  of  1000
# Buildung rocket:  401  of  1000
# Buildung rocket:  402  of  1000
# Buildung rocket:  403  of  1000
# Buildung rocket:  404  of  1000
# Buildung rocket:  405  of  1000
# Buildung rocket:  406  of  1000
# Buildung rocket:  407  of  1000
# Buildung rocket:  408  of  1000
# Buildung rocket:  409  of  1000
# Buildung rocket:  410  of  1000
# Buildung rocket:  411  of  1000
# Buildung rocket:  412  of  1000
# Buildung rocket:  413  of  1000
# Buildung rocket:  414  of  1000
# Buildung rocket:  415  of  1000
# Buildung rocket:  416  of  1000
# Buildung rocket:  417  of  1000
# Buildung rocket:  418  of  1000
# Buildung rocket:  419  of  1000
# Buildung rocket:  420  of  1000
# Buildung rocket:  421  of  1000
# Buildung rocket:  422  of  1000
# Buildung rocket:  423  of  1000
# Buildung rocket:  424  of  1000
# Buildung rocket:  425  of  1000
# Buildung rocket:  426  of  1000
# Buildung rocket:  427  of  1000
# Buildung rocket:  428  of  1000
# Buildung rocket:  429  of  1000
# Buildung rocket:  430  of  1000
# Buildung rocket:  431  of  1000
# Buildung rocket:  432  of  1000
# Buildung rocket:  433  of  1000
# Buildung rocket:  434  of  1000
# Buildung rocket:  435  of  1000
# Buildung rocket:  436  of  1000
# Buildung rocket:  437  of  1000
# Buildung rocket:  438  of  1000
# Buildung rocket:  439  of  1000
# Buildung rocket:  440  of  1000
# Buildung rocket:  441  of  1000
# Buildung rocket:  442  of  1000
# Buildung rocket:  443  of  1000
# Buildung rocket:  444  of  1000
# Buildung rocket:  445  of  1000
# Buildung rocket:  446  of  1000
# Buildung rocket:  447  of  1000
# Buildung rocket:  448  of  1000
# Buildung rocket:  449  of  1000
# Buildung rocket:  450  of  1000
# Buildung rocket:  451  of  1000
# Buildung rocket:  452  of  1000
# Buildung rocket:  453  of  1000
# Buildung rocket:  454  of  1000
# Buildung rocket:  455  of  1000
# Buildung rocket:  456  of  1000
# Buildung rocket:  457  of  1000
# Buildung rocket:  458  of  1000
# Buildung rocket:  459  of  1000
# Buildung rocket:  460  of  1000
# Buildung rocket:  461  of  1000
# Buildung rocket:  462  of  1000
# Buildung rocket:  463  of  1000
# Buildung rocket:  464  of  1000
# Buildung rocket:  465  of  1000
# Buildung rocket:  466  of  1000
# Buildung rocket:  467  of  1000
# Buildung rocket:  468  of  1000
# Buildung rocket:  469  of  1000
# Buildung rocket:  470  of  1000
# Buildung rocket:  471  of  1000
# Buildung rocket:  472  of  1000
# Buildung rocket:  473  of  1000
# Buildung rocket:  474  of  1000
# Buildung rocket:  475  of  1000
# Buildung rocket:  476  of  1000
# Buildung rocket:  477  of  1000
# Buildung rocket:  478  of  1000
# Buildung rocket:  479  of  1000
# Buildung rocket:  480  of  1000
# Buildung rocket:  481  of  1000
# Buildung rocket:  482  of  1000
# Buildung rocket:  483  of  1000
# Buildung rocket:  484  of  1000
# Buildung rocket:  485  of  1000
# Buildung rocket:  486  of  1000
# Buildung rocket:  487  of  1000
# Buildung rocket:  488  of  1000
# Buildung rocket:  489  of  1000
# Buildung rocket:  490  of  1000
# Buildung rocket:  491  of  1000
# Buildung rocket:  492  of  1000
# Buildung rocket:  493  of  1000
# Buildung rocket:  494  of  1000
# Buildung rocket:  495  of  1000
# Buildung rocket:  496  of  1000
# Buildung rocket:  497  of  1000
# Buildung rocket:  498  of  1000
# Buildung rocket:  499  of  1000
# Buildung rocket:  500  of  1000
# Buildung rocket:  501  of  1000
# Buildung rocket:  502  of  1000
# Buildung rocket:  503  of  1000
# Buildung rocket:  504  of  1000
# Buildung rocket:  505  of  1000
# Buildung rocket:  506  of  1000
# Buildung rocket:  507  of  1000
# Buildung rocket:  508  of  1000
# Buildung rocket:  509  of  1000
# Buildung rocket:  510  of  1000
# Buildung rocket:  511  of  1000
# Buildung rocket:  512  of  1000
# Buildung rocket:  513  of  1000
# Buildung rocket:  514  of  1000
# Buildung rocket:  515  of  1000
# Buildung rocket:  516  of  1000
# Buildung rocket:  517  of  1000
# Buildung rocket:  518  of  1000
# Buildung rocket:  519  of  1000
# Buildung rocket:  520  of  1000
# Buildung rocket:  521  of  1000
# Buildung rocket:  522  of  1000
# Buildung rocket:  523  of  1000
# Buildung rocket:  524  of  1000
# Buildung rocket:  525  of  1000
# Buildung rocket:  526  of  1000
# Buildung rocket:  527  of  1000
# Buildung rocket:  528  of  1000
# Buildung rocket:  529  of  1000
# Buildung rocket:  530  of  1000
# Buildung rocket:  531  of  1000
# Buildung rocket:  532  of  1000
# Buildung rocket:  533  of  1000
# Buildung rocket:  534  of  1000
# Buildung rocket:  535  of  1000
# Buildung rocket:  536  of  1000
# Buildung rocket:  537  of  1000
# Buildung rocket:  538  of  1000
# Buildung rocket:  539  of  1000
# Buildung rocket:  540  of  1000
# Buildung rocket:  541  of  1000
# Buildung rocket:  542  of  1000
# Buildung rocket:  543  of  1000
# Buildung rocket:  544  of  1000
# Buildung rocket:  545  of  1000
# Buildung rocket:  546  of  1000
# Buildung rocket:  547  of  1000
# Buildung rocket:  548  of  1000
# Buildung rocket:  549  of  1000
# Buildung rocket:  550  of  1000
# Buildung rocket:  551  of  1000
# Buildung rocket:  552  of  1000
# Buildung rocket:  553  of  1000
# Buildung rocket:  554  of  1000
# Buildung rocket:  555  of  1000
# Buildung rocket:  556  of  1000
# Buildung rocket:  557  of  1000
# Buildung rocket:  558  of  1000
# Buildung rocket:  559  of  1000
# Buildung rocket:  560  of  1000
# Buildung rocket:  561  of  1000
# Buildung rocket:  562  of  1000
# Buildung rocket:  563  of  1000
# Buildung rocket:  564  of  1000
# Buildung rocket:  565  of  1000
# Buildung rocket:  566  of  1000
# Buildung rocket:  567  of  1000
# Buildung rocket:  568  of  1000
# Buildung rocket:  569  of  1000
# Buildung rocket:  570  of  1000
# Buildung rocket:  571  of  1000
# Buildung rocket:  572  of  1000
# Buildung rocket:  573  of  1000
# Buildung rocket:  574  of  1000
# Buildung rocket:  575  of  1000
# Buildung rocket:  576  of  1000
# Buildung rocket:  577  of  1000
# Buildung rocket:  578  of  1000
# Buildung rocket:  579  of  1000
# Buildung rocket:  580  of  1000
# Buildung rocket:  581  of  1000
# Buildung rocket:  582  of  1000
# Buildung rocket:  583  of  1000
# Buildung rocket:  584  of  1000
# Buildung rocket:  585  of  1000
# Buildung rocket:  586  of  1000
# Buildung rocket:  587  of  1000
# Buildung rocket:  588  of  1000
# Buildung rocket:  589  of  1000
# Buildung rocket:  590  of  1000
# Buildung rocket:  591  of  1000
# Buildung rocket:  592  of  1000
# Buildung rocket:  593  of  1000
# Buildung rocket:  594  of  1000
# Buildung rocket:  595  of  1000
# Buildung rocket:  596  of  1000
# Buildung rocket:  597  of  1000
# Buildung rocket:  598  of  1000
# Buildung rocket:  599  of  1000
# Buildung rocket:  600  of  1000
# Buildung rocket:  601  of  1000
# Buildung rocket:  602  of  1000
# Buildung rocket:  603  of  1000
# Buildung rocket:  604  of  1000
# Buildung rocket:  605  of  1000
# Buildung rocket:  606  of  1000
# Buildung rocket:  607  of  1000
# Buildung rocket:  608  of  1000
# Buildung rocket:  609  of  1000
# Buildung rocket:  610  of  1000
# Buildung rocket:  611  of  1000
# Buildung rocket:  612  of  1000
# Buildung rocket:  613  of  1000
# Buildung rocket:  614  of  1000
# Buildung rocket:  615  of  1000
# Buildung rocket:  616  of  1000
# Buildung rocket:  617  of  1000
# Buildung rocket:  618  of  1000
# Buildung rocket:  619  of  1000
# Buildung rocket:  620  of  1000
# Buildung rocket:  621  of  1000
# Buildung rocket:  622  of  1000
# Buildung rocket:  623  of  1000
# Buildung rocket:  624  of  1000
# Buildung rocket:  625  of  1000
# Buildung rocket:  626  of  1000
# Buildung rocket:  627  of  1000
# Buildung rocket:  628  of  1000
# Buildung rocket:  629  of  1000
# Buildung rocket:  630  of  1000
# Buildung rocket:  631  of  1000
# Buildung rocket:  632  of  1000
# Buildung rocket:  633  of  1000
# Buildung rocket:  634  of  1000
# Buildung rocket:  635  of  1000
# Buildung rocket:  636  of  1000
# Buildung rocket:  637  of  1000
# Buildung rocket:  638  of  1000
# Buildung rocket:  639  of  1000
# Buildung rocket:  640  of  1000
# Buildung rocket:  641  of  1000
# Buildung rocket:  642  of  1000
# Buildung rocket:  643  of  1000
# Buildung rocket:  644  of  1000
# Buildung rocket:  645  of  1000
# Buildung rocket:  646  of  1000
# Buildung rocket:  647  of  1000
# Buildung rocket:  648  of  1000
# Buildung rocket:  649  of  1000
# Buildung rocket:  650  of  1000
# Buildung rocket:  651  of  1000
# Buildung rocket:  652  of  1000
# Buildung rocket:  653  of  1000
# Buildung rocket:  654  of  1000
# Buildung rocket:  655  of  1000
# Buildung rocket:  656  of  1000
# Buildung rocket:  657  of  1000
# Buildung rocket:  658  of  1000
# Buildung rocket:  659  of  1000
# Buildung rocket:  660  of  1000
# Buildung rocket:  661  of  1000
# Buildung rocket:  662  of  1000
# Buildung rocket:  663  of  1000
# Buildung rocket:  664  of  1000
# Buildung rocket:  665  of  1000
# Buildung rocket:  666  of  1000
# Buildung rocket:  667  of  1000
# Buildung rocket:  668  of  1000
# Buildung rocket:  669  of  1000
# Buildung rocket:  670  of  1000
# Buildung rocket:  671  of  1000
# Buildung rocket:  672  of  1000
# Buildung rocket:  673  of  1000
# Buildung rocket:  674  of  1000
# Buildung rocket:  675  of  1000
# Buildung rocket:  676  of  1000
# Buildung rocket:  677  of  1000
# Buildung rocket:  678  of  1000
# Buildung rocket:  679  of  1000
# Buildung rocket:  680  of  1000
# Buildung rocket:  681  of  1000
# Buildung rocket:  682  of  1000
# Buildung rocket:  683  of  1000
# Buildung rocket:  684  of  1000
# Buildung rocket:  685  of  1000
# Buildung rocket:  686  of  1000
# Buildung rocket:  687  of  1000
# Buildung rocket:  688  of  1000
# Buildung rocket:  689  of  1000
# Buildung rocket:  690  of  1000
# Buildung rocket:  691  of  1000
# Buildung rocket:  692  of  1000
# Buildung rocket:  693  of  1000
# Buildung rocket:  694  of  1000
# Buildung rocket:  695  of  1000
# Buildung rocket:  696  of  1000
# Buildung rocket:  697  of  1000
# Buildung rocket:  698  of  1000
# Buildung rocket:  699  of  1000
# Buildung rocket:  700  of  1000
# Buildung rocket:  701  of  1000
# Buildung rocket:  702  of  1000
# Buildung rocket:  703  of  1000
# Buildung rocket:  704  of  1000
# Buildung rocket:  705  of  1000
# Buildung rocket:  706  of  1000
# Buildung rocket:  707  of  1000
# Buildung rocket:  708  of  1000
# Buildung rocket:  709  of  1000
# Buildung rocket:  710  of  1000
# Buildung rocket:  711  of  1000
# Buildung rocket:  712  of  1000
# Buildung rocket:  713  of  1000
# Buildung rocket:  714  of  1000
# Buildung rocket:  715  of  1000
# Buildung rocket:  716  of  1000
# Buildung rocket:  717  of  1000
# Buildung rocket:  718  of  1000
# Buildung rocket:  719  of  1000
# Buildung rocket:  720  of  1000
# Buildung rocket:  721  of  1000
# Buildung rocket:  722  of  1000
# Buildung rocket:  723  of  1000
# Buildung rocket:  724  of  1000
# Buildung rocket:  725  of  1000
# Buildung rocket:  726  of  1000
# Buildung rocket:  727  of  1000
# Buildung rocket:  728  of  1000
# Buildung rocket:  729  of  1000
# Buildung rocket:  730  of  1000
# Buildung rocket:  731  of  1000
# Buildung rocket:  732  of  1000
# Buildung rocket:  733  of  1000
# Buildung rocket:  734  of  1000
# Buildung rocket:  735  of  1000
# Buildung rocket:  736  of  1000
# Buildung rocket:  737  of  1000
# Buildung rocket:  738  of  1000
# Buildung rocket:  739  of  1000
# Buildung rocket:  740  of  1000
# Buildung rocket:  741  of  1000
# Buildung rocket:  742  of  1000
# Buildung rocket:  743  of  1000
# Buildung rocket:  744  of  1000
# Buildung rocket:  745  of  1000
# Buildung rocket:  746  of  1000
# Buildung rocket:  747  of  1000
# Buildung rocket:  748  of  1000
# Buildung rocket:  749  of  1000
# Buildung rocket:  750  of  1000
# Buildung rocket:  751  of  1000
# Buildung rocket:  752  of  1000
# Buildung rocket:  753  of  1000
# Buildung rocket:  754  of  1000
# Buildung rocket:  755  of  1000
# Buildung rocket:  756  of  1000
# Buildung rocket:  757  of  1000
# Buildung rocket:  758  of  1000
# Buildung rocket:  759  of  1000
# Buildung rocket:  760  of  1000
# Buildung rocket:  761  of  1000
# Buildung rocket:  762  of  1000
# Buildung rocket:  763  of  1000
# Buildung rocket:  764  of  1000
# Buildung rocket:  765  of  1000
# Buildung rocket:  766  of  1000
# Buildung rocket:  767  of  1000
# Buildung rocket:  768  of  1000
# Buildung rocket:  769  of  1000
# Buildung rocket:  770  of  1000
# Buildung rocket:  771  of  1000
# Buildung rocket:  772  of  1000
# Buildung rocket:  773  of  1000
# Buildung rocket:  774  of  1000
# Buildung rocket:  775  of  1000
# Buildung rocket:  776  of  1000
# Buildung rocket:  777  of  1000
# Buildung rocket:  778  of  1000
# Buildung rocket:  779  of  1000
# Buildung rocket:  780  of  1000
# Buildung rocket:  781  of  1000
# Buildung rocket:  782  of  1000
# Buildung rocket:  783  of  1000
# Buildung rocket:  784  of  1000
# Buildung rocket:  785  of  1000
# Buildung rocket:  786  of  1000
# Buildung rocket:  787  of  1000
# Buildung rocket:  788  of  1000
# Buildung rocket:  789  of  1000
# Buildung rocket:  790  of  1000
# Buildung rocket:  791  of  1000
# Buildung rocket:  792  of  1000
# Buildung rocket:  793  of  1000
# Buildung rocket:  794  of  1000
# Buildung rocket:  795  of  1000
# Buildung rocket:  796  of  1000
# Buildung rocket:  797  of  1000
# Buildung rocket:  798  of  1000
# Buildung rocket:  799  of  1000
# Buildung rocket:  800  of  1000
# Buildung rocket:  801  of  1000
# Buildung rocket:  802  of  1000
# Buildung rocket:  803  of  1000
# Buildung rocket:  804  of  1000
# Buildung rocket:  805  of  1000
# Buildung rocket:  806  of  1000
# Buildung rocket:  807  of  1000
# Buildung rocket:  808  of  1000
# Buildung rocket:  809  of  1000
# Buildung rocket:  810  of  1000
# Buildung rocket:  811  of  1000
# Buildung rocket:  812  of  1000
# Buildung rocket:  813  of  1000
# Buildung rocket:  814  of  1000
# Buildung rocket:  815  of  1000
# Buildung rocket:  816  of  1000
# Buildung rocket:  817  of  1000
# Buildung rocket:  818  of  1000
# Buildung rocket:  819  of  1000
# Buildung rocket:  820  of  1000
# Buildung rocket:  821  of  1000
# Buildung rocket:  822  of  1000
# Buildung rocket:  823  of  1000
# Buildung rocket:  824  of  1000
# Buildung rocket:  825  of  1000
# Buildung rocket:  826  of  1000
# Buildung rocket:  827  of  1000
# Buildung rocket:  828  of  1000
# Buildung rocket:  829  of  1000
# Buildung rocket:  830  of  1000
# Buildung rocket:  831  of  1000
# Buildung rocket:  832  of  1000
# Buildung rocket:  833  of  1000
# Buildung rocket:  834  of  1000
# Buildung rocket:  835  of  1000
# Buildung rocket:  836  of  1000
# Buildung rocket:  837  of  1000
# Buildung rocket:  838  of  1000
# Buildung rocket:  839  of  1000
# Buildung rocket:  840  of  1000
# Buildung rocket:  841  of  1000
# Buildung rocket:  842  of  1000
# Buildung rocket:  843  of  1000
# Buildung rocket:  844  of  1000
# Buildung rocket:  845  of  1000
# Buildung rocket:  846  of  1000
# Buildung rocket:  847  of  1000
# Buildung rocket:  848  of  1000
# Buildung rocket:  849  of  1000
# Buildung rocket:  850  of  1000
# Buildung rocket:  851  of  1000
# Buildung rocket:  852  of  1000
# Buildung rocket:  853  of  1000
# Buildung rocket:  854  of  1000
# Buildung rocket:  855  of  1000
# Buildung rocket:  856  of  1000
# Buildung rocket:  857  of  1000
# Buildung rocket:  858  of  1000
# Buildung rocket:  859  of  1000
# Buildung rocket:  860  of  1000
# Buildung rocket:  861  of  1000
# Buildung rocket:  862  of  1000
# Buildung rocket:  863  of  1000
# Buildung rocket:  864  of  1000
# Buildung rocket:  865  of  1000
# Buildung rocket:  866  of  1000
# Buildung rocket:  867  of  1000
# Buildung rocket:  868  of  1000
# Buildung rocket:  869  of  1000
# Buildung rocket:  870  of  1000
# Buildung rocket:  871  of  1000
# Buildung rocket:  872  of  1000
# Buildung rocket:  873  of  1000
# Buildung rocket:  874  of  1000
# Buildung rocket:  875  of  1000
# Buildung rocket:  876  of  1000
# Buildung rocket:  877  of  1000
# Buildung rocket:  878  of  1000
# Buildung rocket:  879  of  1000
# Buildung rocket:  880  of  1000
# Buildung rocket:  881  of  1000
# Buildung rocket:  882  of  1000
# Buildung rocket:  883  of  1000
# Buildung rocket:  884  of  1000
# Buildung rocket:  885  of  1000
# Buildung rocket:  886  of  1000
# Buildung rocket:  887  of  1000
# Buildung rocket:  888  of  1000
# Buildung rocket:  889  of  1000
# Buildung rocket:  890  of  1000
# Buildung rocket:  891  of  1000
# Buildung rocket:  892  of  1000
# Buildung rocket:  893  of  1000
# Buildung rocket:  894  of  1000
# Buildung rocket:  895  of  1000
# Buildung rocket:  896  of  1000
# Buildung rocket:  897  of  1000
# Buildung rocket:  898  of  1000
# Buildung rocket:  899  of  1000
# Buildung rocket:  900  of  1000
# Buildung rocket:  901  of  1000
# Buildung rocket:  902  of  1000
# Buildung rocket:  903  of  1000
# Buildung rocket:  904  of  1000
# Buildung rocket:  905  of  1000
# Buildung rocket:  906  of  1000
# Buildung rocket:  907  of  1000
# Buildung rocket:  908  of  1000
# Buildung rocket:  909  of  1000
# Buildung rocket:  910  of  1000
# Buildung rocket:  911  of  1000
# Buildung rocket:  912  of  1000
# Buildung rocket:  913  of  1000
# Buildung rocket:  914  of  1000
# Buildung rocket:  915  of  1000
# Buildung rocket:  916  of  1000
# Buildung rocket:  917  of  1000
# Buildung rocket:  918  of  1000
# Buildung rocket:  919  of  1000
# Buildung rocket:  920  of  1000
# Buildung rocket:  921  of  1000
# Buildung rocket:  922  of  1000
# Buildung rocket:  923  of  1000
# Buildung rocket:  924  of  1000
# Buildung rocket:  925  of  1000
# Buildung rocket:  926  of  1000
# Buildung rocket:  927  of  1000
# Buildung rocket:  928  of  1000
# Buildung rocket:  929  of  1000
# Buildung rocket:  930  of  1000
# Buildung rocket:  931  of  1000
# Buildung rocket:  932  of  1000
# Buildung rocket:  933  of  1000
# Buildung rocket:  934  of  1000
# Buildung rocket:  935  of  1000
# Buildung rocket:  936  of  1000
# Buildung rocket:  937  of  1000
# Buildung rocket:  938  of  1000
# Buildung rocket:  939  of  1000
# Buildung rocket:  940  of  1000
# Buildung rocket:  941  of  1000
# Buildung rocket:  942  of  1000
# Buildung rocket:  943  of  1000
# Buildung rocket:  944  of  1000
# Buildung rocket:  945  of  1000
# Buildung rocket:  946  of  1000
# Buildung rocket:  947  of  1000
# Buildung rocket:  948  of  1000
# Buildung rocket:  949  of  1000
# Buildung rocket:  950  of  1000
# Buildung rocket:  951  of  1000
# Buildung rocket:  952  of  1000
# Buildung rocket:  953  of  1000
# Buildung rocket:  954  of  1000
# Buildung rocket:  955  of  1000
# Buildung rocket:  956  of  1000
# Buildung rocket:  957  of  1000
# Buildung rocket:  958  of  1000
# Buildung rocket:  959  of  1000
# Buildung rocket:  960  of  1000
# Buildung rocket:  961  of  1000
# Buildung rocket:  962  of  1000
# Buildung rocket:  963  of  1000
# Buildung rocket:  964  of  1000
# Buildung rocket:  965  of  1000
# Buildung rocket:  966  of  1000
# Buildung rocket:  967  of  1000
# Buildung rocket:  968  of  1000
# Buildung rocket:  969  of  1000
# Buildung rocket:  970  of  1000
# Buildung rocket:  971  of  1000
# Buildung rocket:  972  of  1000
# Buildung rocket:  973  of  1000
# Buildung rocket:  974  of  1000
# Buildung rocket:  975  of  1000
# Buildung rocket:  976  of  1000
# Buildung rocket:  977  of  1000
# Buildung rocket:  978  of  1000
# Buildung rocket:  979  of  1000
# Buildung rocket:  980  of  1000
# Buildung rocket:  981  of  1000
# Buildung rocket:  982  of  1000
# Buildung rocket:  983  of  1000
# Buildung rocket:  984  of  1000
# Buildung rocket:  985  of  1000
# Buildung rocket:  986  of  1000
# Buildung rocket:  987  of  1000
# Buildung rocket:  988  of  1000
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_971 . Skipping...
# Simulating rocket 973 of 1000: Rocket_972
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_972 . Skipping...
# Simulating rocket 974 of 1000: Rocket_973
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_973 . Skipping...
# Simulating rocket 975 of 1000: Rocket_974
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_974 . Skipping...
# Simulating rocket 976 of 1000: Rocket_975
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_975 . Skipping...
# Simulating rocket 977 of 1000: Rocket_976
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_976 . Skipping...
# Simulating rocket 978 of 1000: Rocket_977
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_977 . Skipping...
# Simulating rocket 979 of 1000: Rocket_978
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_978 . Skipping...
# Simulating rocket 980 of 1000: Rocket_979
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_979 . Skipping...
# Simulating rocket 981 of 1000: Rocket_980
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_980 . Skipping...
# Simulating rocket 982 of 1000: Rocket_981
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_981 . Skipping...
# Simulating rocket 983 of 1000: Rocket_982
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_982 . Skipping...
# Simulating rocket 984 of 1000: Rocket_983
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_983 . Skipping...
# Simulating rocket 985 of 1000: Rocket_984
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_984 . Skipping...
# Simulating rocket 986 of 1000: Rocket_985
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_985 . Skipping...
# Simulating rocket 987 of 1000: Rocket_986
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_986 . Skipping...
# Simulating rocket 988 of 1000: Rocket_987
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_987 . Skipping...
# Simulating rocket 989 of 1000: Rocket_988
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_988 . Skipping...
# Simulating rocket 990 of 1000: Rocket_989
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_989 . Skipping...
# Simulating rocket 991 of 1000: Rocket_990
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_990 . Skipping...
# Simulating rocket 992 of 1000: Rocket_991
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_991 . Skipping...
# Simulating rocket 993 of 1000: Rocket_992
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_992 . Skipping...
# Simulating rocket 994 of 1000: Rocket_993
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_993 . Skipping...
# Simulating rocket 995 of 1000: Rocket_994
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_994 . Skipping...
# Simulating rocket 996 of 1000: Rocket_995
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_995 . Skipping...
# Simulating rocket 997 of 1000: Rocket_996
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_996 . Skipping...
# Simulating rocket 998 of 1000: Rocket_997
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_997 . Skipping...
# Simulating rocket 999 of 1000: Rocket_998
# reading cea isp data files for N2O / ETHANOL 1000 times
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_998 . Skipping...
# Simulating rocket 1000 of 1000: Rocket_999
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_999 . Skipping...
# All rockets simulated. Closing hdf5 file...

# %% [markdown]
# Plot the results

# %%
#create performance plotter
pP = plotting.PerformancePlotter(file_path)

#plot 1d
#pP.plot_1D(x="of",
#            y = "metrics.apogee",
#           xlabel="O/F [-]",
#           ylabel="Apogee [m]",)

"""pP.plot_1D(x="of",
            y = ["tanks.ETHANOLtank.mass","tanks.N2Otank.mass","tanks.HELIUMtank.mass"],
              xlabel="O/F [-]",
                ylabel="Tank Mass [kg]",)
"""
#plot 2d 
pP.plot_2D(x="chamberPressure",
           y="pressurantTankPressure",
           z="metrics.apogee",
           xlabel="Chamber Pressure [Pa]",
           ylabel="Pressurant Tank Pressure [Pa]",
           zlabel="Apogee [m]",)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 16
#      10 """pP.plot_1D(x="of",
#      11             y = ["tanks.ETHANOLtank.mass","tanks.N2Otank.mass","tanks.HELIUMtank.mass"],
#      12               xlabel="O/F [-]",
#      13                 ylabel="Tank Mass [kg]",)
#      14 """
#      15 #plot 2d
# ---> 16 pP.plot_2D(x="chamberPressure",
#      17            y="pressurantTankPressure",
#      18            z="metrics.apogee",
#      19            xlabel="Chamber Pressure [Pa]",
#      20            ylabel="Pressurant Tank Pressure [Pa]",
#      21            zlabel="Apogee [m]",)
#
# File ~\Documents\HyTEMPO\hytempo\core\plotting.py:331, in PerformancePlotter.plot_2D(self, x, y, z, xlabel, ylabel, zlabel, export_path)
#     328 f = plt.figure()
#     329 ax = f.add_subplot(111)
# --> 331 tcf = ax.tricontourf(xData, yData, zData)
#     333 cb = f.colorbar(tcf)
#     335 if xlabel is None:
#
# File c:\Users\klein\Documents\HyTEMPO\.venv\Lib\site-packages\matplotlib\tri\_tricontour.py:270, in tricontourf(ax, *args, **kwargs)
#     252 """
#     253 %(_tricontour_doc)s
#     254
#    (...)    267 includes the lowest value).
#     268 """
#     269 kwargs['filled'] = True
# --> 270 return TriContourSet(ax, *args, **kwargs)
#
# File c:\Users\klein\Documents\HyTEMPO\.venv\Lib\site-packages\matplotlib\tri\_tricontour.py:29, in TriContourSet.__init__(self, ax, *args, **kwargs)
#      19 def __init__(self, ax, *args, **kwargs):
#      20     """
#      21     Draw triangular grid contour lines or filled regions,
#      22     depending on whether keyword arg *filled* is False
#    (...)     27     are described in the docstring of `~.Axes.tricontour`.
#      28     """
# ---> 29     super().__init__(ax, *args, **kwargs)
#
# File c:\Users\klein\Documents\HyTEMPO\.venv\Lib\site-packages\matplotlib\contour.py:701, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     697 if self.negative_linestyles is None:
#     698     self.negative_linestyles = \
#     699         mpl.rcParams['contour.negative_linestyle']
# --> 701 kwargs = self._process_args(*args, **kwargs)
#     702 self._process_levels()
#     704 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\klein\Documents\HyTEMPO\.venv\Lib\site-packages\matplotlib\tri\_tricontour.py:45, in TriContourSet._process_args(self, *args, **kwargs)
#      43 else:
#      44     from matplotlib import _tri
# ---> 45     tri, z = self._contour_args(args, kwargs)
#      46     C = _tri.TriContourGenerator(tri.get_cpp_triangulation(), z)
#      47     self._mins = [tri.x.min(), tri.y.min()]
#
# File c:\Users\klein\Documents\HyTEMPO\.venv\Lib\site-packages\matplotlib\tri\_tricontour.py:54, in TriContourSet._contour_args(self, args, kwargs)
#      53 def _contour_args(self, args, kwargs):
# ---> 54     tri, args, kwargs = Triangulation.get_from_args_and_kwargs(*args,
#      55                                                                **kwargs)
#      56     z, *args = args
#      57     z = np.ma.asarray(z)
#
# File c:\Users\klein\Documents\HyTEMPO\.venv\Lib\site-packages\matplotlib\tri\_triangulation.py:167, in Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#     164 else:
#     165     x, y, triangles, mask, args, kwargs = \
#     166         Triangulation._extract_triangulation_params(args, kwargs)
# --> 167     triangulation = Triangulation(x, y, triangles, mask)
#     168 return triangulation, args, kwargs
#
# File c:\Users\klein\Documents\HyTEMPO\.venv\Lib\site-packages\matplotlib\tri\_triangulation.py:60, in Triangulation.__init__(self, x, y, triangles, mask)
#      55 self.is_delaunay = False
#      57 if triangles is None:
#      58     # No triangulation specified, so use matplotlib._qhull to obtain
#      59     # Delaunay triangulation.
# ---> 60     self.triangles, self._neighbors = _qhull.delaunay(x, y, sys.flags.verbose)
#      61     self.is_delaunay = True
#      62 else:
#      63     # Triangulation specified. Copy, since we may correct triangle
#      64     # orientation.
#
# ValueError: x and y arrays must have a length of at least 3
