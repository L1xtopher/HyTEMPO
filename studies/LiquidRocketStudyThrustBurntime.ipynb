# %%
import os
import numpy as np
from hytempo.core import rocketfactory,trajectory_estimator,components,rocket,plotting,data_handling
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# Setup Parameters

# %%
"create components"
#create structures
nosecone = components.Component(mass=1,name="structures",length=0.53,hulltube=False)
radaxe = components.Component(mass=2.0,name="radaxe",length=0.05,hulltube=False)
finnen = components.Component(mass=2.0,name="fins",length=0.0,hulltube=False)
boattail = components.Component(mass=0.200,name="boattail",length=0.0,hulltube=False)

# subsystems
avionic = components.Component(mass=1.8,name="avionic",length=0.25,hulltube=True)
recovery = components.Component(mass=4.020,name="recovery",length=0.25,hulltube=True)
fluid_system = components.Component(mass=7.0,name="fluid_system",length=0.98,hulltube=True)
parts = []

parts.append(nosecone)
parts.append(radaxe)
parts.append(finnen)
parts.append(boattail)
parts.append(avionic)
parts.append(recovery)
parts.append(fluid_system)


"Import CD LUT"
absolute_path = os.path.dirname(os.path.abspath("__file__"))
relative_path = "hytempo\LUTs\CD_Map.csv"
absolute_path = absolute_path[:absolute_path.rfind("\\") ]                 
path = os.path.join(absolute_path, relative_path)
CD_tab = np.genfromtxt(path, delimiter=";")

"Setup variables"
#diameters = [0.1,0.2]
burn_times = [10,45]
thrust = [6000,10000]
#of = [4.5,6]
#chamberPressure = [5e6,8e6]
#expansionRatio = [10,20]
#pressurantPressureFactor = [2,6]
#launch_angle = [80,85]

diameters = 0.25
#burn_times = 30
#thrust = 8000
of = 4.8
chamberPressure = 6e6
expansionRatio = 10
pressurantPressureFactor = 5
launch_angle = 88

# %% [markdown]
# Build and simulate the rockets

# %%
#create the hdf5 file
name = "LiquidSim"
hdf_file = data_handling.create_hdf5_file(name, overwrite=False)

#create rockets
factory = rocketfactory.Liquid_CEA_TypeVTank_RegNitrous()
rockets = factory.build_swarm(
    hdf_file=hdf_file,
    diameters = diameters,
    burnTimes = burn_times,
    thrusts = thrust,
    ofs = of,
    chamberPressures = chamberPressure,
    expansionRatios = expansionRatio,
    pressurantPressureFactors = pressurantPressureFactor,
    launchAngles=launch_angle,
    componentList=parts,
    fuel="ETHANOL",
    fuelTemp=300,
    ox="N2O",
    oxTemp=300,
    pressurant="HELIUM",
    pressurantTemp=300,
    dragCoefficient=CD_tab,
    engineMass=4,
    engineLength=0.3,
    fuelTankSafetyFactor=1.5,
    oxTankSafetyFactor=1.5,
    pressurantTankSafetyFactor=1.5,
    thicknessEndCap=0.0015,
    cfrpTensileStrength=600e6,
    nRockets=100)

#loop over rockets and simulate trajectories
print(f"Start simulating {len(rockets)} rockets...")
for i,indRocket in enumerate(rockets):
    #create estimator and simulate trajectory
    print(f"Simulating rocket {i+1} of {len(rockets)}: {indRocket.name}")
    sim = trajectory_estimator.TrajectoryEstimator(indRocket,hdf_file)
    try:
        trajectory = sim.integrate_trajectory()
    except Exception as e:
        print("ERROR:")
        print(e)
        print(f"Simulation failed for rocket {indRocket.name} . Skipping...")
print("All rockets simulated. Closing hdf5 file...")    
#close the hdf5 file
file_path = data_handling.close_hdf5_file(hdf_file)
# Out:
# Setting up factory for rockets with:
#  - Single liquid engine with CEA isp model
#  - Type V CFK tanks for fuel, oxidizer and pressurant
#  - Regenerative cooling with Nitrous oxide
# Start building rockets!
# Buildung rocket:  1  of  100
# Buildung rocket:  2  of  100
# Buildung rocket:  3  of  100
# Buildung rocket:  4  of  100
# Buildung rocket:  5  of  100
# Buildung rocket:  6  of  100
# Buildung rocket:  7  of  100
# Buildung rocket:  8  of  100
# Buildung rocket:  9  of  100
# Buildung rocket:  10  of  100
# Buildung rocket:  11  of  100
# Buildung rocket:  12  of  100
# Buildung rocket:  13  of  100
# Buildung rocket:  14  of  100
# Buildung rocket:  15  of  100
# Buildung rocket:  16  of  100
# Buildung rocket:  17  of  100
# Buildung rocket:  18  of  100
# Buildung rocket:  19  of  100
# Buildung rocket:  20  of  100
# Buildung rocket:  21  of  100
# Buildung rocket:  22  of  100
# Buildung rocket:  23  of  100
# Buildung rocket:  24  of  100
# Buildung rocket:  25  of  100
# Buildung rocket:  26  of  100
# Buildung rocket:  27  of  100
# Buildung rocket:  28  of  100
# Buildung rocket:  29  of  100
# Buildung rocket:  30  of  100
# Buildung rocket:  31  of  100
# Buildung rocket:  32  of  100
# Buildung rocket:  33  of  100
# Buildung rocket:  34  of  100
# Buildung rocket:  35  of  100
# Buildung rocket:  36  of  100
# Buildung rocket:  37  of  100
# Buildung rocket:  38  of  100
# Buildung rocket:  39  of  100
# Buildung rocket:  40  of  100
# Buildung rocket:  41  of  100
# Buildung rocket:  42  of  100
# Buildung rocket:  43  of  100
# Buildung rocket:  44  of  100
# Buildung rocket:  45  of  100
# Buildung rocket:  46  of  100
# Buildung rocket:  47  of  100
# Buildung rocket:  48  of  100
# Buildung rocket:  49  of  100
# Buildung rocket:  50  of  100
# Buildung rocket:  51  of  100
# Buildung rocket:  52  of  100
# Buildung rocket:  53  of  100
# Buildung rocket:  54  of  100
# Buildung rocket:  55  of  100
# Buildung rocket:  56  of  100
# Buildung rocket:  57  of  100
# Buildung rocket:  58  of  100
# Buildung rocket:  59  of  100
# Buildung rocket:  60  of  100
# Buildung rocket:  61  of  100
# Buildung rocket:  62  of  100
# Buildung rocket:  63  of  100
# Buildung rocket:  64  of  100
# Buildung rocket:  65  of  100
# Buildung rocket:  66  of  100
# Buildung rocket:  67  of  100
# Buildung rocket:  68  of  100
# Buildung rocket:  69  of  100
# Buildung rocket:  70  of  100
# Buildung rocket:  71  of  100
# Buildung rocket:  72  of  100
# Buildung rocket:  73  of  100
# Buildung rocket:  74  of  100
# Buildung rocket:  75  of  100
# Buildung rocket:  76  of  100
# Buildung rocket:  77  of  100
# Buildung rocket:  78  of  100
# Buildung rocket:  79  of  100
# Buildung rocket:  80  of  100
# Buildung rocket:  81  of  100
# Buildung rocket:  82  of  100
# Buildung rocket:  83  of  100
# Buildung rocket:  84  of  100
# Buildung rocket:  85  of  100
# Buildung rocket:  86  of  100
# Buildung rocket:  87  of  100
# Buildung rocket:  88  of  100
# Buildung rocket:  89  of  100
# Buildung rocket:  90  of  100
# Buildung rocket:  91  of  100
# Buildung rocket:  92  of  100
# Buildung rocket:  93  of  100
# Buildung rocket:  94  of  100
# Buildung rocket:  95  of  100
# Buildung rocket:  96  of  100
# Buildung rocket:  97  of  100
# Buildung rocket:  98  of  100
# Buildung rocket:  99  of  100
# Buildung rocket:  100  of  100
# Start simulating 100 rockets...
# Simulating rocket 1 of 100: Rocket_0
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_0 . Skipping...
# Simulating rocket 2 of 100: Rocket_1
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_1 . Skipping...
# Simulating rocket 3 of 100: Rocket_2
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_2 . Skipping...
# Simulating rocket 4 of 100: Rocket_3
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_3 . Skipping...
# Simulating rocket 5 of 100: Rocket_4
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_4 . Skipping...
# Simulating rocket 6 of 100: Rocket_5
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_5 . Skipping...
# Simulating rocket 7 of 100: Rocket_6
# Simulating rocket 8 of 100: Rocket_7
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_7 . Skipping...
# Simulating rocket 9 of 100: Rocket_8
# Simulating rocket 10 of 100: Rocket_9
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_9 . Skipping...
# Simulating rocket 11 of 100: Rocket_10
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_10 . Skipping...
# Simulating rocket 12 of 100: Rocket_11
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_11 . Skipping...
# Simulating rocket 13 of 100: Rocket_12
# Simulating rocket 14 of 100: Rocket_13
# Simulating rocket 15 of 100: Rocket_14
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_14 . Skipping...
# Simulating rocket 16 of 100: Rocket_15
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_15 . Skipping...
# Simulating rocket 17 of 100: Rocket_16
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_16 . Skipping...
# Simulating rocket 18 of 100: Rocket_17
# Simulating rocket 19 of 100: Rocket_18
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_18 . Skipping...
# Simulating rocket 20 of 100: Rocket_19
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_19 . Skipping...
# Simulating rocket 21 of 100: Rocket_20
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_20 . Skipping...
# Simulating rocket 22 of 100: Rocket_21
# Simulating rocket 23 of 100: Rocket_22
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_22 . Skipping...
# Simulating rocket 24 of 100: Rocket_23
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_23 . Skipping...
# Simulating rocket 25 of 100: Rocket_24
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_24 . Skipping...
# Simulating rocket 26 of 100: Rocket_25
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_25 . Skipping...
# Simulating rocket 27 of 100: Rocket_26
# Simulating rocket 28 of 100: Rocket_27
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_27 . Skipping...
# Simulating rocket 29 of 100: Rocket_28
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_28 . Skipping...
# Simulating rocket 30 of 100: Rocket_29
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_29 . Skipping...
# Simulating rocket 31 of 100: Rocket_30
# Simulating rocket 32 of 100: Rocket_31
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_31 . Skipping...
# Simulating rocket 33 of 100: Rocket_32
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_32 . Skipping...
# Simulating rocket 34 of 100: Rocket_33
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_33 . Skipping...
# Simulating rocket 35 of 100: Rocket_34
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_34 . Skipping...
# Simulating rocket 36 of 100: Rocket_35
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_35 . Skipping...
# Simulating rocket 37 of 100: Rocket_36
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_36 . Skipping...
# Simulating rocket 38 of 100: Rocket_37
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_37 . Skipping...
# Simulating rocket 39 of 100: Rocket_38
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_38 . Skipping...
# Simulating rocket 40 of 100: Rocket_39
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_39 . Skipping...
# Simulating rocket 41 of 100: Rocket_40
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_40 . Skipping...
# Simulating rocket 42 of 100: Rocket_41
# Simulating rocket 43 of 100: Rocket_42
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_42 . Skipping...
# Simulating rocket 44 of 100: Rocket_43
# Simulating rocket 45 of 100: Rocket_44
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_44 . Skipping...
# Simulating rocket 46 of 100: Rocket_45
# Simulating rocket 47 of 100: Rocket_46
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_46 . Skipping...
# Simulating rocket 48 of 100: Rocket_47
# Simulating rocket 49 of 100: Rocket_48
# Simulating rocket 50 of 100: Rocket_49
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_49 . Skipping...
# Simulating rocket 51 of 100: Rocket_50
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_50 . Skipping...
# Simulating rocket 52 of 100: Rocket_51
# Simulating rocket 53 of 100: Rocket_52
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_52 . Skipping...
# Simulating rocket 54 of 100: Rocket_53
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_53 . Skipping...
# Simulating rocket 55 of 100: Rocket_54
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_54 . Skipping...
# Simulating rocket 56 of 100: Rocket_55
# Simulating rocket 57 of 100: Rocket_56
# Simulating rocket 58 of 100: Rocket_57
# Simulating rocket 59 of 100: Rocket_58
# Simulating rocket 60 of 100: Rocket_59
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_59 . Skipping...
# Simulating rocket 61 of 100: Rocket_60
# Simulating rocket 62 of 100: Rocket_61
# Simulating rocket 63 of 100: Rocket_62
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_62 . Skipping...
# Simulating rocket 64 of 100: Rocket_63
# Simulating rocket 65 of 100: Rocket_64
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_64 . Skipping...
# Simulating rocket 66 of 100: Rocket_65
# Simulating rocket 67 of 100: Rocket_66
# Simulating rocket 68 of 100: Rocket_67
# Simulating rocket 69 of 100: Rocket_68
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_68 . Skipping...
# Simulating rocket 70 of 100: Rocket_69
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_69 . Skipping...
# Simulating rocket 71 of 100: Rocket_70
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_70 . Skipping...
# Simulating rocket 72 of 100: Rocket_71
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_71 . Skipping...
# Simulating rocket 73 of 100: Rocket_72
# Simulating rocket 74 of 100: Rocket_73
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_73 . Skipping...
# Simulating rocket 75 of 100: Rocket_74
# Simulating rocket 76 of 100: Rocket_75
# Simulating rocket 77 of 100: Rocket_76
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_76 . Skipping...
# Simulating rocket 78 of 100: Rocket_77
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_77 . Skipping...
# Simulating rocket 79 of 100: Rocket_78
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_78 . Skipping...
# Simulating rocket 80 of 100: Rocket_79
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_79 . Skipping...
# Simulating rocket 81 of 100: Rocket_80
# Simulating rocket 82 of 100: Rocket_81
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_81 . Skipping...
# Simulating rocket 83 of 100: Rocket_82
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_82 . Skipping...
# Simulating rocket 84 of 100: Rocket_83
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_83 . Skipping...
# Simulating rocket 85 of 100: Rocket_84
# Simulating rocket 86 of 100: Rocket_85
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_85 . Skipping...
# Simulating rocket 87 of 100: Rocket_86
# Simulating rocket 88 of 100: Rocket_87
# Simulating rocket 89 of 100: Rocket_88
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_88 . Skipping...
# Simulating rocket 90 of 100: Rocket_89
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_89 . Skipping...
# Simulating rocket 91 of 100: Rocket_90
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_90 . Skipping...
# Simulating rocket 92 of 100: Rocket_91
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_91 . Skipping...
# Simulating rocket 93 of 100: Rocket_92
# Simulating rocket 94 of 100: Rocket_93
# Simulating rocket 95 of 100: Rocket_94
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_94 . Skipping...
# Simulating rocket 96 of 100: Rocket_95
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_95 . Skipping...
# Simulating rocket 97 of 100: Rocket_96
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_96 . Skipping...
# Simulating rocket 98 of 100: Rocket_97
# Simulating rocket 99 of 100: Rocket_98
# reading cea isp data files for N2O / ETHANOL 100 times
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_98 . Skipping...
# Simulating rocket 100 of 100: Rocket_99
# ERROR:
# One of the requested xi is out of bounds in dimension 1
# Simulation failed for rocket Rocket_99 . Skipping...
# All rockets simulated. Closing hdf5 file...

# %% [markdown]
# Plot the results

# %%
#create performance plotter
pP = plotting.PerformancePlotter(file_path)

#plot 1d
#pP.plot_1D(x="of",
#            y = "metrics.apogee",
#           xlabel="O/F [-]",
#           ylabel="Apogee [m]",)

"""pP.plot_1D(x="of",
            y = ["tanks.ETHANOLtank.mass","tanks.N2Otank.mass","tanks.HELIUMtank.mass"],
              xlabel="O/F [-]",
                ylabel="Tank Mass [kg]",)
"""
#plot 2d 
pP.plot_2D(x="thrust",
           y="burnTime",
           z="metrics.apogee",
           xlabel="Thrust [N]",
           ylabel="Burn time [s]",
           zlabel="Apogee [m]",)
